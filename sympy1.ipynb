# %% [markdown]
# # Работа с библиотекой SymPy

# %% [markdown]
# ### Инициализация

# %% [markdown]
# Наиболее удобным способом работы с библиотекой SymPy является использование `jupyter-notebook`. При этом для визуализации математических формул желательно наличие работоспособного дистрибутива LaTeX. Начинать работу следует с инициализации, которая часто будет сводиться к выполнению следующих трёх команд:

# %%
from sympy import *
init_printing()
# %matplotlib inline
from sympy.solvers.inequalities import solve_poly_inequalities
from sympy.polys import Poly
var('a b c d e f g h i j x y x1 x2 x3 x4 x5 x6 x7 x8 x9 x10 y1 y2 y3 y4 y5 y6 y7 y8 y9 y10')
# Out:
# (a, b, c, d, e, f, g, h, i, j, x, y, x₁, x₂, x₃, x₄, x₅, x₆, x₇, x₈, x₉, x₁₀,
# y₁, y₂, y₃, y₄, y₅, y₆, y₇, y₈, y₉, y₁₀)

# %%
print()
# #A(EXP(-EXP(-B(X-C))))
# var('a b c d f g h i j x y x1 x2 x3 x4 x5 x6 x7 x8 x9 x10 y1 y2 y3 y4 y5 y6 y7 y8 y9 y10')
# f9 = a*(3**(-3**(-b*(x-c))))-y
# f1 = f9.subs({x: 2, y: 334.22})
# f2 = f9.subs({x: 10 , y: 334.014})
# f3 = f9.subs({x: 50 , y: 196.14})
# f4 = f9.subs({x: 100, y: 149.08})
# f5 = f9.subs({x: 250 , y: 50.77})
# f6 = f9.subs({x: 400 , y: 24.42})
# f7 = f9.subs({x: 700 , y: 16.23})
# f8 = f9.subs({x: 600  , y: 17.32})
# f10 = f9.subs({x: 1000  , y: 11.78})
# f11 = f9.subs({x: 500.0  , y: 20.30})
# print(solve([f1, f2, f3], {a,b,c}))

# %%
#A(EXP(-EXP(-B(X-C))))
var('a b c d e f g h i j x y x1 x2 x3 x4 x5 x6 x7 x8 x9 x10 y1 y2 y3 y4 y5 y6 y7 y8 y9 y10')
f9 = (a+b*x**3+c*x**4)/(d+e*x**3+f*x**4)+g -y
# f13 = (1+f*x+e*x**2+a*x**3+b*x**4)/(1+c*x**3+d*x**4) - y
f1 = f9.subs({x: 2, y: 334.22})
f2 = f9.subs({x: 10 , y: 334.014})
f3 = f9.subs({x: 50 , y: 196.14})
f4 = f9.subs({x: 100, y: 149.08})
f5 = f9.subs({x: 250 , y: 50.77})
f6 = f9.subs({x: 400 , y: 24.42})
f7 = f9.subs({x: 700 , y: 16.23})
f8 = f9.subs({x: 600  , y: 17.32})
f10 = f9.subs({x: 1000  , y: 11.78})
f11 = f9.subs({x: 500.0  , y: 20.30})
f12 = f9.subs({x: 30  , y: 332.3631300224079})
# f13 = (1+f*x+g*x**2+h*x**3+i*x**4)/(1+f*x+g*x**2+h*x**3+i*x**4)-1
# f14 = (a+b*x+c*x**2+d*x**3+e*x**4)/(a+b*x+c*x**2+d*x**3+e*x**4)-1
# f14 = abs(1+f*x+g*x**2+h*x**3+i*x**4)/(1+f*x+g*x**2+h*x**3+i*x**4)-1
# f14 = f13.subs({x: 2, y: 334.22})
# f15 = f13.subs({x: 10 , y: 334.014})
# f16 = f13.subs({x: 50 , y: 196.14})
# f17 = f13.subs({x: 100, y: 149.08})
# f18 = f13.subs({x: 250 , y: 50.77})
# f19 = f13.subs({x: 400 , y: 24.42})
# f20 = f13.subs({x: 700 , y: 16.23})
# f21 = f13.subs({x: 600  , y: 17.32})
# f22 = f13.subs({x: 1000  , y: 11.78})
# f23 = f13.subs({x: 500.0  , y: 20.30})
# f24 = f13.subs({x: 30  , y: 332.3631300224079})
# f13 = (1+f*x+g*x**2+h*x**3+i*x**4)/(1+f*x+g*x**2+h*x**3+i*x**4) - 1
slv = solve([f1,f2,f3,f4,f7,f6,f8], {a,b,c,d,e,f,g})
for aa in str(slv).replace("{","").replace("}","").replace(" ", "").replace("e","*10^{").split(','):
    if aa.__contains__("{"):
        aa = aa + "}"
    print(aa)

# solve_univariate_inequality(f13 > 0, (a, b, c, d,e,f,g,h,i), relational=True)

# print(slv[0][a].subs({b: -0.16047}).subs({x1: 2, y1: 334.22, x2: 10, y2:334.01, x3: 50, y3: 196.14}))
# print(slv[0][c].subs({b: -0.16047}).subs({x1: 2, y1: 334.22, x2: 10, y2:334.01, x3: 50, y3: 196.14}))
# print(-0.16047)
# tmp = simplify(f3.subs({a : slv[0][a], c: slv[0][c]}))
# print(tmp.subs({x1: 2, y1: 334.22, x2: 10, y2:334.01, x3: 50, y3: 196.14}))
# f1 = f9.subs({x: 2, y: 334.22})
# f2 = f9.subs({x: 10 , y: 334.014})
# f3 = f9.subs({x: 50 , y: 196.14})
# solve_poly_inequalities(((
# solve_rational_inequalities([[
# ((Poly(f1), Poly(0)), '=='),
# ((Poly(-x + 1), Poly(1, x)), '<=')]])
# Poly(f1), "=="), (Poly(f2), "=="), (Poly(f3), "=="), (Poly(f4), "=="), (Poly(f5), "=="),
# (Poly(f6), "=="), (Poly(f7), "=="), (Poly(f8), "=="), (Poly(f11), "=="),
# (Poly(f12), "=="), (Poly(f13), "!=")))
# Out:
# []

# %%
for i in range(200, 1600):
    print(f"[{i/2}, {i/2}]", end=", ")
for i in range(800, 1000, 10):
    print(f"[{i}, {i}]", end=", ")
for i in range(40, 2000):
    print(f"[{i/20}, {i/20}]", end=", ")
# Out:
# [100.0, 100.0], [100.5, 100.5], [101.0, 101.0], [101.5, 101.5], [102.0, 102.0], [102.5, 102.5], [103.0, 103.0], [103.5, 103.5], [104.0, 104.0], [104.5, 104.5], [105.0, 105.0], [105.5, 105.5], [106.0, 106.0], [106.5, 106.5], [107.0, 107.0], [107.5, 107.5], [108.0, 108.0], [108.5, 108.5], [109.0, 109.0], [109.5, 109.5], [110.0, 110.0], [110.5, 110.5], [111.0, 111.0], [111.5, 111.5], [112.0, 112.0], [112.5, 112.5], [113.0, 113.0], [113.5, 113.5], [114.0, 114.0], [114.5, 114.5], [115.0, 115.0], [115.5, 115.5], [116.0, 116.0], [116.5, 116.5], [117.0, 117.0], [117.5, 117.5], [118.0, 118.0], [118.5, 118.5], [119.0, 119.0], [119.5, 119.5], [120.0, 120.0], [120.5, 120.5], [121.0, 121.0], [121.5, 121.5], [122.0, 122.0], [122.5, 122.5], [123.0, 123.0], [123.5, 123.5], [124.0, 124.0], [124.5, 124.5], [125.0, 125.0], [125.5, 125.5], [126.0, 126.0], [126.5, 126.5], [127.0, 127.0], [127.5, 127.5], [128.0, 128.0], [128.5, 128.5], [129.0, 129.0], [129.5, 129.5], [130.0, 130.0], [130.5, 130.5], [131.0
# ...
